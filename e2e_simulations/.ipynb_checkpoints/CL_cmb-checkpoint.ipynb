# %%
import numpy as np
import healpy as hp
import pymaster as nmt
import matplotlib.pyplot as plt

# %%
# Inputs

Nside = 64
lmax = 2*Nside-1
Nlbin = 10
Nsims = 100

Npixs = hp.nside2npix(Nside)

bC = nmt.NmtBin.from_lmax_linear(lmax, nlb=Nlbin, is_Dell=False)
bD = nmt.NmtBin.from_lmax_linear(lmax, nlb=Nlbin, is_Dell=True)
leff = bC.get_effective_ells()
Nbins = len(leff)

# %%
# Load and bin DL_cmb

CL_cmb = np.load('CL_cmb_nside64.npy')[:Nsims]
Ncross = CL_cmb.shape[1]

CL_cmb_binned = np.zeros((Nsims, Ncross, Nbins))
DL_cmb_binned = np.zeros((Nsims, Ncross, Nbins))

for i in range(Ncross):
    for k in range(Nsims):
        CL_cmb_binned[k, i] = bC.bin_cell(CL_cmb[k, i, :2*Nside])
        DL_cmb_binned[k, i] = bD.bin_cell(CL_cmb[k, i, :2*Nside])

# Theoretical lensing CMB

ell = np.arange(2, 2*Nside)

CL_lens = hp.read_cl('../power_spectra/Cls_Planck2018_r0.fits')[2, 2:2*Nside]
DL_lens = CL_lens * ell*(ell+1) / (2*np.pi)

# %%
for i in range(Ncross):
    plt.errorbar(leff, np.mean(DL_cmb_binned[:, i], axis=0), yerr=np.std(DL_cmb_binned[:, i], axis=0), fmt='o', alpha=0.01)
plt.loglog(ell, DL_lens, linewidth=2, color='red')
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\mathcal{D}_\ell^{\rm CMB}$ [$\mu$K$^2$]')
plt.xlim(2, 2*Nside-1)
plt.show()

for i in range(Ncross):
    plt.errorbar(leff, np.mean(CL_cmb_binned[:, i], axis=0), yerr=np.std(CL_cmb_binned[:, i], axis=0), fmt='o', alpha=0.01)
plt.loglog(ell, CL_lens, linewidth=2, color='red')
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\mathcal{C}_\ell^{\rm CMB}$ [$\mu$K$^2$]')
plt.xlim(2, 2*Nside-1)
plt.show()
