# %%
import sys
sys.path.append('../lib/')
import numpy as np
import healpy as hp
import pymaster as nmt
import matplotlib.pyplot as plt
from tqdm import trange
import simu_lib as sim

# %%
# Inputs

Nside = 64
lmax = 2*Nside-1
Nlbin = 10
Nsims = 250

Npixs = hp.nside2npix(Nside)

# %%
# Load instrument

instr_name = 'litebird_full'
instr =  np.load("../lib/instr_dict/%s.npy"%instr_name,allow_pickle=True).item()

freq = instr['frequencies']
sens = instr['sens_P']
beam = instr['beams']

Nfreqs = len(freq)
Ncross = int(Nfreqs*(Nfreqs+1) / 2)

sigma = sens / hp.nside2resol(Nside, arcmin=True)

# %%
# Load and bin DL_noise

b = nmt.NmtBin.from_lmax_linear(lmax, nlb=Nlbin, is_Dell=False)
leff = b.get_effective_ells()
Nbins = len(leff)

CL_noise = np.load('./DL_noise_nside%s_full.npy' % (Nside))[:Nsims]
CL_noise_binned = np.zeros((Nsims, Ncross, 2, Nbins))

for s in range(Nsims):
    for c in range(Ncross):
        CL_noise_binned[s, c, 0] = b.bin_cell(np.concatenate((np.zeros(2), CL_noise[s, c, 0, :2*Nside-2]))) #EE
        CL_noise_binned[s, c, 1] = b.bin_cell(np.concatenate((np.zeros(2), CL_noise[s, c, 1, :2*Nside-2]))) #BB

# %%
ell = np.arange(2, 3*Nside)

for i in range(Ncross): #Ncross
    plt.errorbar(leff, np.mean(CL_noise_binned[:, i], axis=(0,1)), yerr=np.std(CL_noise_binned[:, i], axis=(0,1)), fmt='o')
    plt.show()

# %%
# Workspace

b = nmt.NmtBin.from_nside_linear(64, nlb=Nlbin, is_Dell=True)
f1 = nmt.NmtField(mask64, None, spin=2, purify_b=True)
f2 = nmt.NmtField(mask64, None, spin=2, purify_b=True)
w64 = nmt.NmtWorkspace()
w64.compute_coupling_matrix(f1, f2, b)

# %%
for i in trange(10):
    f1 = nmt.NmtField(mask64, cmb64[i, 1:], spin=2, purify_b=True)
    f2 = nmt.NmtField(mask64, cmb64[i, 1:], spin=2, purify_b=True)
    sim.compute_master(f1, f2, w64)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 for i in trange(10):
#       2     f1 = nmt.NmtField(mask64, cmb64[i, 1:], spin=2, purify_b=True)
#       3     f2 = nmt.NmtField(mask64, cmb64[i, 1:], spin=2, purify_b=True)
#
# File ~/miniconda3/envs/dust/lib/python3.12/site-packages/tqdm/notebook.py:312, in tnrange(*args, **kwargs)
#     310 def tnrange(*args, **kwargs):
#     311     """Shortcut for `tqdm.notebook.tqdm(range(*args), **kwargs)`."""
# --> 312     return tqdm_notebook(range(*args), **kwargs)
#
# File ~/miniconda3/envs/dust/lib/python3.12/site-packages/tqdm/notebook.py:234, in tqdm_notebook.__init__(self, *args, **kwargs)
#     232 unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     233 total = self.total * unit_scale if self.total else self.total
# ...

# %%
for i in trange(10):
    f1 = nmt.NmtField(mask512, cmb512[i, 1:], spin=2, purify_b=True, lmax=3*64-1)
    f2 = nmt.NmtField(mask512, cmb512[i, 1:], spin=2, purify_b=True, lmax=3*64-1)
    sim.compute_master(f1, f2, w64)
# Out:
#   0%|          | 0/10 [00:06<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 for i in trange(10):
# ----> 2     f1 = nmt.NmtField(mask512, cmb512[i, 1:], spin=2, purify_b=True, lmax=3*64-1)
#       3     f2 = nmt.NmtField(mask512, cmb512[i, 1:], spin=2, purify_b=True, lmax=3*64-1)
#       4     sim.compute_master(f1, f2, w64)
#
# File ~/miniconda3/envs/dust/lib/python3.12/site-packages/pymaster/field.py:322, in NmtField.__init__(self, mask, maps, spin, templates, beam, purify_e, purify_b, n_iter, n_iter_mask, tol_pinv, wcs, lmax, lmax_mask, masked_on_input, lite, mask_22, mask_12)
#     320 task = [self.pure_e, self.pure_b]
#     321 alm_mask = self.get_mask_alms()
# --> 322 self.alm, maps = self._purify(self.mask, alm_mask, maps_unmasked,
#     323                               n_iter=n_iter, task=task)
# ...
